# %%
import pysd
from pathlib import Path

vensimDirectory='Prosumers & defectors'
vensimFile ='net metering-no fixed tariff.mdl'
filepath = Path(vensimDirectory,vensimFile)
model = pysd.read_vensim(str(filepath))
stocks = model.run()
print(stocks.shape)
# Out:
# (241, 112)

# %%
stocks[["Electricity Tariff","Budget Deficit","Utility Energy Sale"]].plot()
# Out:
# <AxesSubplot:>

# %%
stocks[["Variable Costs","Fixed Costs","Total Costs"]].plot()
# Out:
# <AxesSubplot:>

# %%
stocks.loc[1:50,["Variable Costs","Fixed Costs","Total Costs"]].plot()
# Out:
# <AxesSubplot:>

# %%
results = model.run(params={'Fixed Costs':5e7})

# %%
results.loc[1:50,["Variable Costs","Fixed Costs","Total Costs"]].plot()
# Out:
# <AxesSubplot:>

# %%
results["Electricity Tariff"].plot()
# Out:
# <AxesSubplot:>

# %%
results[["Defectors","Prosumers","Regular Consumers"]].plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
electricity_sales = pd.read_csv("../Data/Retail_sales_of_electricity.csv")
